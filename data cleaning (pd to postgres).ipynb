# %%
import pandas as pd
from flask import (
    Flask,
    render_template,
    jsonify,
    request,
    redirect)
from sqlalchemy import create_engine

# %%
file_2015= 'data/2015.csv'
df_2015 = pd.read_csv(file_2015)
file_2016= 'data/2016.csv'
df_2016 = pd.read_csv(file_2016)
file_2017= 'data/2017.csv'
df_2017 = pd.read_csv(file_2017)
file_2018= 'data/2018.csv'
df_2018 = pd.read_csv(file_2018)
file_2019= 'data/2019.csv'
df_2019 = pd.read_csv(file_2019)

# %%
#cleaning DFs 
df2015_cleaned=df_2015.drop(columns=['Standard Error', 'Family', 'Dystopia Residual', 'Region'])
#add year column 
df2015_cleaned['Year']='2015'
df2015_cleaned.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Year
# 0     0.29678  2015
# 1     0.43630  2015
# 2     0.34139  2015
# 3     0.34699  2015
# 4     0.45811  2015

# %%
df2016_cleaned= df_2016.drop(columns=['Region','Lower Confidence Interval', 'Upper Confidence Interval', 'Family', 'Dystopia Residual'])
df2016_cleaned['Year']='2016'
df2016_cleaned.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0      Denmark               1            7.526                   1.44178
# 1  Switzerland               2            7.509                   1.52733
# 2      Iceland               3            7.501                   1.42666
# 3       Norway               4            7.498                   1.57744
# 4      Finland               5            7.413                   1.40598
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.79504  0.57941                        0.44453
# 1                   0.86303  0.58557                        0.41203
# 2                   0.86733  0.56624                        0.14975
# 3                   0.79579  0.59609                        0.35776
# 4                   0.81091  0.57104                        0.41004
#
#    Generosity  Year
# 0     0.36171  2016
# 1     0.28083  2016
# 2     0.47678  2016
# 3     0.37895  2016
# 4     0.25492  2016

# %%
df2017_cleaned=df_2017.drop(columns=['Whisker high','Whisker low', 'Family', 'Dystopia Residual'])
df2017_cleaned=df2017_cleaned.rename(columns={'Economy GDP per Capita': 'Economy (GDP per Capita)', 'Health Life Expectancy':'Health (Life Expectancy)','Trust Government Corruption.': 'Trust (Government Corruption)' })
df2017_cleaned['Year']='2017'

df2017_cleaned
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      Economy (GDP per Capita)  Health (Life Expectancy)   Freedom  Generosity  \
# 0                    1.616463                  0.796667  0.635423    0.362012
# 1                    1.482383                  0.792566  0.626007    0.355280
# 2                    1.480633                  0.833552  0.627163    0.475540
# 3                    1.564980                  0.858131  0.620071    0.290549
# 4                    1.443572                  0.809158  0.617951    0.245483
# ..                        ...                       ...       ...         ...
# 150                  0.368746                  0.326425  0.581844    0.252756
# 151                  0.777153                  0.500533  0.081539    0.493664
# 152                  0.511136                  0.364509  0.390018    0.354256
# 153                  0.091623                  0.151611  0.059901    0.204435
# 154                  0.000000                  0.018773  0.270842    0.280876
#
#      Trust (Government Corruption)  Year
# 0                         0.315964  2017
# 1                         0.400770  2017
# 2                         0.153527  2017
# 3                         0.367007  2017
# 4                         0.382612  2017
# ..                             ...   ...
# 150                       0.455220  2017
# 151                       0.151347  2017
# 152                       0.066035  2017
# 153                       0.084148  2017
# 154                       0.056565  2017
#
# [155 rows x 9 columns]

# %%
df2018_cleaned=df_2018.drop(columns=['Social support'])
df2018_cleaned.columns
df2018_cleaned=df2018_cleaned.rename(columns={'Country or region':'Country','Overall rank': 'Happiness Rank', 'Score': 'Happiness Score', 'GDP per capita': 'Economy (GDP per Capita)', 'Healthy life expectancy':'Health (Life Expectancy)','Freedom to make life choices':'Freedom', 'Perceptions of corruption': 'Trust (Government Corruption)'})
df2018_cleaned['Year']='2018'

df2018_cleaned
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                   Finland            7.632
# 1                 2                    Norway            7.594
# 2                 3                   Denmark            7.555
# 3                 4                   Iceland            7.495
# 4                 5               Switzerland            7.487
# ..              ...                       ...              ...
# 151             152                     Yemen            3.355
# 152             153                  Tanzania            3.303
# 153             154               South Sudan            3.254
# 154             155  Central African Republic            3.083
# 155             156                   Burundi            2.905
#
#      Economy (GDP per Capita)  Health (Life Expectancy)  Freedom  Generosity  \
# 0                       1.305                     0.874    0.681       0.202
# 1                       1.456                     0.861    0.686       0.286
# 2                       1.351                     0.868    0.683       0.284
# 3                       1.343                     0.914    0.677       0.353
# 4                       1.420                     0.927    0.660       0.256
# ..                        ...                       ...      ...         ...
# 151                     0.442                     0.343    0.244       0.083
# 152                     0.455                     0.381    0.481       0.270
# 153                     0.337                     0.177    0.112       0.224
# 154                     0.024                     0.010    0.305       0.218
# 155                     0.091                     0.145    0.065       0.149
#
#      Trust (Government Corruption)  Year
# 0                            0.393  2018
# 1                            0.340  2018
# 2                            0.408  2018
# 3                            0.138  2018
# 4                            0.357  2018
# ..                             ...   ...
# 151                          0.064  2018
# 152                          0.097  2018
# 153                          0.106  2018
# 154                          0.038  2018
# 155                          0.076  2018
#
# [156 rows x 9 columns]

# %%
df2019_cleaned=df_2019.drop(columns=['Social support' ])
df2019_cleaned=df2019_cleaned.rename(columns={'Overall rank': 'Happiness Rank', 'Score': 'Happiness Score', 'GDP per capita': 'Economy (GDP per Capita)', 'Healthy life expectancy':'Health (Life Expectancy)','Freedom to make life choices':'Freedom', 'Perceptions of corruption': 'Trust (Government Corruption)','Country or region':'Country'})
df2019_cleaned['Year']='2019'
df2019_cleaned
# Out:
#      Happiness Rank                   Country  Happiness Score  \
# 0                 1                   Finland            7.769
# 1                 2                   Denmark            7.600
# 2                 3                    Norway            7.554
# 3                 4                   Iceland            7.494
# 4                 5               Netherlands            7.488
# ..              ...                       ...              ...
# 151             152                    Rwanda            3.334
# 152             153                  Tanzania            3.231
# 153             154               Afghanistan            3.203
# 154             155  Central African Republic            3.083
# 155             156               South Sudan            2.853
#
#      Economy (GDP per Capita)  Health (Life Expectancy)  Freedom  Generosity  \
# 0                       1.340                     0.986    0.596       0.153
# 1                       1.383                     0.996    0.592       0.252
# 2                       1.488                     1.028    0.603       0.271
# 3                       1.380                     1.026    0.591       0.354
# 4                       1.396                     0.999    0.557       0.322
# ..                        ...                       ...      ...         ...
# 151                     0.359                     0.614    0.555       0.217
# 152                     0.476                     0.499    0.417       0.276
# 153                     0.350                     0.361    0.000       0.158
# 154                     0.026                     0.105    0.225       0.235
# 155                     0.306                     0.295    0.010       0.202
#
#      Trust (Government Corruption)  Year
# 0                            0.393  2019
# 1                            0.410  2019
# 2                            0.341  2019
# 3                            0.118  2019
# 4                            0.298  2019
# ..                             ...   ...
# 151                          0.411  2019
# 152                          0.147  2019
# 153                          0.025  2019
# 154                          0.035  2019
# 155                          0.091  2019
#
# [156 rows x 9 columns]

# %%
#merging all dataframes
# merged=result = df1.append(df2)
happiness_df=df2015_cleaned.append([df2016_cleaned,df2017_cleaned, df2018_cleaned, df2019_cleaned])

# %%
happiness_df.columns
# Out:
# Index(['Country', 'Happiness Rank', 'Happiness Score',
#        'Economy (GDP per Capita)', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Year'],
#       dtype='object')

# %%
happiness_df = happiness_df.rename(columns={'Happiness Rank':'Happiness_Rank',
                             'Happiness Score':'Happiness_Score',
                             'Economy (GDP per Capita)':'Economy',
                             'Health (Life Expectancy)':'Health', 
                             'Trust (Government Corruption)': 'Trust'})

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func , desc

# %%
# connection = Connection()
# db = connection.database_name
# input_data = db.collection_name
# data = pd.DataFrame(list(input_data.find()))

# %%
import sqlite3
from sqlite3 import Error

# %%
# def create_connection(db_file):
#     conn = None
#     try: 
#         conn=sqlite3.connect(db_file)
#         print(sqlite3.version)
#     except Error as e:
#         print(e)

# %%
# if _name_=='_main_':
#     create_connection(r"C:\sqlite\db\pythonsqlite.db")

# %%
engine = create_engine("sqlite:///happiness.sqlite")

# %%
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# []

# %%
session = Session(engine)

# %%
conn=sqlite3.connect('happiness.sqlite')

# %%
happiness_df.to_sql('happiness_df_3',conn)

# %%
# conn = sql.connect('weather.db')
# weather = pd.read_sql('SELECT * FROM weather', conn)
happiness_rank=pd.read_sql('SELECT * FROM happiness_df_3',conn)

# %%
happiness_rank
# Out:
#      index                   Country  Happiness_Rank  Happiness_Score  \
# 0        0               Switzerland               1            7.587
# 1        1                   Iceland               2            7.561
# 2        2                   Denmark               3            7.527
# 3        3                    Norway               4            7.522
# 4        4                    Canada               5            7.427
# ..     ...                       ...             ...              ...
# 777    151                    Rwanda             152            3.334
# 778    152                  Tanzania             153            3.231
# 779    153               Afghanistan             154            3.203
# 780    154  Central African Republic             155            3.083
# 781    155               South Sudan             156            2.853
#
#      Economy   Health  Freedom    Trust  Generosity  Year
# 0    1.39651  0.94143  0.66557  0.41978     0.29678  2015
# 1    1.30232  0.94784  0.62877  0.14145     0.43630  2015
# 2    1.32548  0.87464  0.64938  0.48357     0.34139  2015
# 3    1.45900  0.88521  0.66973  0.36503     0.34699  2015
# 4    1.32629  0.90563  0.63297  0.32957     0.45811  2015
# ..       ...      ...      ...      ...         ...   ...
# 777  0.35900  0.61400  0.55500  0.41100     0.21700  2019
# 778  0.47600  0.49900  0.41700  0.14700     0.27600  2019
# 779  0.35000  0.36100  0.00000  0.02500     0.15800  2019
# 780  0.02600  0.10500  0.22500  0.03500     0.23500  2019
# 781  0.30600  0.29500  0.01000  0.09100     0.20200  2019
#
# [782 rows x 10 columns]

# %%
happiness_data = []
for index, row in happiness_rank.iterrows():
    current_row ={}
    current_row["Country"]= row.Country
    current_row["Freedom"]= row.Freedom
    happiness_data.append (current_row)
   # print(row.Country, row.Freedom)

# %%
jsonify(happiness_data)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-31-4c85e6548ccb> in <module>
# ----> 1 jsonify(happiness_data)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/flask/json/__init__.py in jsonify(*args, **kwargs)
#     356     separators = (",", ":")
#     357
# --> 358     if current_app.config["JSONIFY_PRETTYPRINT_REGULAR"] or current_app.debug:
#     359         indent = 2
#     360         separators = (", ", ": ")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/werkzeug/local.py in __getattr__(self, name)
#     345         if name == "__members__":
#     346             return dir(self._get_current_object())
# --> 347         return getattr(self._get_current_object(), name)
#     348
#     349     def __setitem__(self, key, value):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/werkzeug/local.py in _get_current_object(self)
#     304         """
#     305         if not hasattr(self.__local, "__release_local__"):
# --> 306             return self.__local()
#     307         try:
#     308             return getattr(self.__local, self.__name__)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/flask/globals.py in _find_app()
#      50     top = _app_ctx_stack.top
#      51     if top is None:
# ---> 52         raise RuntimeError(_app_ctx_err_msg)
#      53     return top.app
#      54
#
# RuntimeError: Working outside of application context.
#
# This typically means that you attempted to use functionality that needed
# to interface with the current application object in some way. To solve
# this, set up an application context with app.app_context().  See the
# documentation for more information.
